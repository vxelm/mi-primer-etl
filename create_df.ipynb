# %%
import pandas as pd

# %%
data = {'Nombre': ['Tu', 'Zenbook'], 'Potencia': ['Alta', '50 TOPS']}
df = pd.DataFrame(data)
print(df)
# Out:
#     Nombre Potencia
# 0       Tu     Alta
# 1  Zenbook  50 TOPS
